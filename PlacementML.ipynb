# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('datasets/studentplacementdata.csv')
df.head()
# Out:
#   gender shortlists  college                  branch  10th  12th  grad  \
# 0      F      CISCO        3              Mechanical     9     8     7
# 1      M        TCS        2  Production Engineering     8     7     8
# 2      F      WIPRO        3              Mechanical     7     6     6
# 3      F         3M        3  Production Engineering     9     8     8
# 4      M         3M        2              Mechanical     8     7     8
#
#    gap_years  workex_month workex_sector
# 0          2            24            IT
# 1          1            26    Consulting
# 2          2            19    Operations
# 3          3             0       Fresher
# 4          2             0       Fresher

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         904 non-null    object
#  1   shortlists     904 non-null    object
#  2   college        904 non-null    int64
#  3   branch         904 non-null    object
#  4   10th           904 non-null    int64
#  5   12th           904 non-null    int64
#  6   grad           904 non-null    int64
#  7   gap_years      904 non-null    int64
#  8   workex_month   904 non-null    int64
#  9   workex_sector  904 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 70.8+ KB

# %%
df.isna().sum()
# Out:
# gender           0
# shortlists       0
# college          0
# branch           0
# 10th             0
# 12th             0
# grad             0
# gap_years        0
# workex_month     0
# workex_sector    0
# dtype: int64

# %%
df.describe()
# Out:
#           college        10th        12th        grad   gap_years  \
# count  904.000000  904.000000  904.000000  904.000000  904.000000
# mean     2.540929    8.652655    8.387168    7.648230    1.445796
# std      0.688849    0.594301    0.685631    0.699737    0.700691
# min      1.000000    6.000000    6.000000    5.000000    1.000000
# 25%      2.000000    8.000000    8.000000    7.000000    1.000000
# 50%      3.000000    9.000000    8.000000    8.000000    1.000000
# 75%      3.000000    9.000000    9.000000    8.000000    2.000000
# max      3.000000    9.000000    9.000000    9.000000    3.000000
#
#        workex_month
# count    904.000000
# mean      17.704646
# std       14.494591
# min        0.000000
# 25%        0.000000
# 50%       20.500000
# 75%       26.000000
# max       59.000000

# %%
df['gender'].replace({'F':0,'M':1},inplace=True)

# %%
df.head()
# Out:
#    gender shortlists  college                  branch  10th  12th  grad  \
# 0       0      CISCO        3              Mechanical     9     8     7
# 1       1        TCS        2  Production Engineering     8     7     8
# 2       0      WIPRO        3              Mechanical     7     6     6
# 3       0         3M        3  Production Engineering     9     8     8
# 4       1         3M        2              Mechanical     8     7     8
#
#    gap_years  workex_month workex_sector
# 0          2            24            IT
# 1          1            26    Consulting
# 2          2            19    Operations
# 3          3             0       Fresher
# 4          2             0       Fresher

# %%
df['branch'].unique()
# Out:
# array(['Mechanical', 'Production Engineering', 'CSE',
#        'Electronics and Telecommunication  ', 'Manufacturing',
#        'Industrial and Production engineering',
#        'Electrical and Electronics', 'Agricultural Engineering',
#        'Textile', 'Information Technology', 'Chemical Engineering',
#        'Electrical Engineering', 'Mining Engineering',
#        'Electronics & Instrumentation',
#        'Instrumentation and Control Engineering', 'Civil', 'Aerospace',
#        'Marine Engineering'], dtype=object)

# %%
df['branch'].replace({'Mechanical':0, 'Production Engineering':1, 'CSE':2,
       'Electronics and Telecommunication  ':3, 'Manufacturing':4,
       'Industrial and Production engineering':5,
       'Electrical and Electronics':6, 'Agricultural Engineering':7,
       'Textile':17, 'Information Technology':8, 'Chemical Engineering':9,
       'Electrical Engineering':10, 'Mining Engineering':11,
       'Electronics & Instrumentation':12,
       'Instrumentation and Control Engineering':13, 'Civil':14, 'Aerospace':15,
       'Marine Engineering':16},inplace=True)

# %%
df
# Out:
#      gender     shortlists  college  branch  10th  12th  grad  gap_years  \
# 0         0          CISCO        3       0     9     8     7          2
# 1         1            TCS        2       1     8     7     8          1
# 2         0          WIPRO        3       0     7     6     6          2
# 3         0             3M        3       1     9     8     8          3
# 4         1             3M        2       0     8     7     8          2
# ..      ...            ...      ...     ...   ...   ...   ...        ...
# 899       1          WIPRO        3      14     9     8     8          1
# 900       1          WIPRO        3      17     6     8     7          1
# 901       1          WIPRO        3       0     9     9     8          1
# 902       1  WONDER CEMENT        3       3     9     9     7          1
# 903       1      YES BANK         2       3     8     8     8          1
#
#      workex_month  workex_sector
# 0              24             IT
# ...

# %%
df['shortlists'].unique()
# Out:
# array(['CISCO', 'TCS', 'WIPRO', '3M', 'ACT', 'AKZONOBEL', 'AMAZON',
#        'AMWAY', 'APOLLO TYRES', 'ASIAN PAINTS', 'ASIAN PAINTS SCM',
#        'ASIAN PAINTS-PPG', ' AXIS BANK', 'BAIN CAPABILITY NETWORK',
#        ' BAKER HUGHES', 'BD', ' BRITANNIA', ' CAPITAL FOODS', ' CIPLA',
#        ' CISCO', ' CUMMINS', ' DEL MONTE', ' DELOITTE', ' DELOITTE USI',
#        ' DIAGEO', ' ETLI', ' FLIPKART', ' FRESENIUS MEDICAL CARE',
#        ' GAVL', ' GCPL', ' GE', ' GENERICO', ' GENERICO ', ' HUL',
#        ' JAIPUR RUGS', ' JAIPUR RUGS ', ' L&T IT', ' MAHINDRA LOGISTICS',
#        ' MC KINSEY DIGITAL', ' MODERN FOODS', ' NIVEA',
#        ' PERFETTI VAN MELLE', ' RPG CEAT', ' SIGNIFY', ' SPARROW RMS',
#        ' SUN PHARMA', ' TATA AIG', ' TCPL', ' TCS', ' TIGER ANALYTICS',
#        ' TITAN', ' WELSPUN', ' WIPRO', ' WONDER CEMENT', ' YES BANK',
#        '3M ', 'ABBOTT', 'ACCENTURE', 'ACCENTURE DIGITAL', 'AMAZON\r\n',
#        'AP', 'AXIS BANK', 'BAKER HUGHES', 'BP CASTROL', 'CASTROL',
# ...

# %%
df['shortlists'].replace({'CISCO':0, 'TCS':1, 'WIPRO':2, '3M':3, 'ACT':4, 'AKZONOBEL':5, 'AMAZON':6,
       'AMWAY':7, 'APOLLO TYRES':8, 'ASIAN PAINTS':9, 'ASIAN PAINTS SCM':10,
       'ASIAN PAINTS-PPG':11, ' AXIS BANK':12, 'BAIN CAPABILITY NETWORK':13,
       ' BAKER HUGHES':14, 'BD':14, ' BRITANNIA':15, ' CAPITAL FOODS':16, ' CIPLA':17,
        ' CUMMINS':18, ' DEL MONTE':19, ' DELOITTE':20, ' DELOITTE USI':21,
       ' DIAGEO':22, ' ETLI':23, ' FLIPKART':24, ' FRESENIUS MEDICAL CARE':25,
       ' GAVL':26, ' GCPL':27, ' GE':28, ' GENERICO':29, ' GENERICO ':30, ' HUL':31,
       ' JAIPUR RUGS':32, ' JAIPUR RUGS ':33, ' L&T IT':34, ' MAHINDRA LOGISTICS':35,
       ' MC KINSEY DIGITAL':35, ' MODERN FOODS':36, ' NIVEA':37,
       ' PERFETTI VAN MELLE':38, ' RPG CEAT':39, ' SIGNIFY':40, ' SPARROW RMS':41,
       ' SUN PHARMA':42, ' TATA AIG':43, ' TCPL':44, ' TCS':45, ' TIGER ANALYTICS':46,
       ' TITAN':47, ' WELSPUN':48, ' WIPRO':49, ' WONDER CEMENT':50, ' YES BANK':51,
       '3M ':52, 'ABBOTT':53, 'ACCENTURE':54, 'ACCENTURE DIGITAL':55, 'AMAZON\r\n':56,
       'AP':57, 'AXIS BANK':58, 'BAKER HUGHES':59, 'BP CASTROL':60, 'CASTROL':61,
       'CIPLA':62, 'CLOUDTAIL':63, 'COLPAL':64, 'CUMMINS':65, 'DABUR':66, 'DELLOITE':67,
       'DELOITTE USI':68, 'DIAGEO':69, 'DRL':70, 'EMAMI AGROTECH':71,
       'FIDELITY INVESTMENTS':72, 'FLIPKART':73, 'FRESH FOOD':74, 'GAVL':75, 'GCPL':76,
       'GE':77, 'GODREJ':78, 'GODREJ AGROVET':79, 'GROFERS':80, 'GSK':81, 'HONEYWELL':82,
       'HP ENTERPRISES':83, 'HUL':84, 'HUL IT ':85, 'ICICI':86, 'IDFC':87, 'ITC':88, 'J&J':89,
       'JAIPUR RUGS':90, 'KCC':91, 'KCC(IT)\r\n\r\n':92, 'L&T':93,
       'MAHINDRA LOGISTICS':94, 'MAHINDRA LOGISTICS ':95, 'MARS':96, 'MARS ':97,
       'MCCAIN':98, 'MCKINSEY DIGITAL':99, 'MIEBACH CONSULTING':100, 'MLL':101,
       'MODERN FOODS':102, 'MONDELEZ':103, 'NESTLE':104, 'NIVEA':105, 'P&G':106, 'PIDILITE':107,
       'PURPELE ':108, 'PWC':109, 'PWC USI':110, 'RB':111, 'SIGNIFY':112, 'SUN PHARMA':113,
       'TATA SKY':114, 'TIGER ANALYTICS':115, 'TIGER ANALYTICS ':116, 'TITAN':117,
       'UNACADEMY':118, 'VODAFONE':119, 'WELLNESS FOREVER':120, 'WONDER CEMENT':121,
       'YES BANK ':123,' CISCO':124},inplace=True)

# %%
df['workex_sector'].unique()
# Out:
# array(['IT', 'Consulting', 'Operations', 'Fresher',
#        'Infrastructure (Construction)', 'Manufacturing', 'BFSI',
#        'Construction', 'Sales and Marketing', 'Oil & Gas', 'FMCG', 'R&D',
#        'Defence and Lidar Technology', 'Engineering and Real Estate',
#        'Engineering Procurement and Construction', 'Metal and Mining',
#        'EPC (engineering procurement and construction)', 'Maritime',
#        'Public service', 'Telecom'], dtype=object)

# %%
df['workex_sector'].replace({'IT':0, 'Consulting':1, 'Operations':2, 'Fresher':3,
       'Infrastructure (Construction)':4, 'Manufacturing':5, 'BFSI':6,
       'Construction':7, 'Sales and Marketing':8, 'Oil & Gas':9, 'FMCG':10, 'R&D':11,
       'Defence and Lidar Technology':12, 'Engineering and Real Estate':13,
       'Engineering Procurement and Construction':14, 'Metal and Mining':15,
       'EPC (engineering procurement and construction)':16, 'Maritime':17,
       'Public service':18, 'Telecom':19},inplace=True)

# %%
df
# Out:
#      gender  shortlists  college  branch  10th  12th  grad  gap_years  \
# 0         0           0        3       0     9     8     7          2
# 1         1           1        2       1     8     7     8          1
# 2         0           2        3       0     7     6     6          2
# 3         0           3        3       1     9     8     8          3
# 4         1           3        2       0     8     7     8          2
# ..      ...         ...      ...     ...   ...   ...   ...        ...
# 899       1           2        3      14     9     8     8          1
# 900       1           2        3      17     6     8     7          1
# 901       1           2        3       0     9     9     8          1
# 902       1         121        3       3     9     9     7          1
# 903       1         123        2       3     8     8     8          1
#
#      workex_month  workex_sector
# 0              24              0
# 1              26              1
# ...

# %%
x = df.drop('gender',axis=1)
y= df['gender']

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 899    1
# 900    1
# 901    1
# 902    1
# 903    1
# Name: gender, Length: 904, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
lr = LogisticRegression()
lr.fit(X_train,Y_train)

svm = svm.SVC()
svm.fit(X_train,Y_train)

knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)

dt=DecisionTreeClassifier()
dt.fit(X_train,Y_train)

rf=RandomForestClassifier()
rf.fit(X_train,Y_train)

gb=GradientBoostingClassifier()
gb.fit(X_train,Y_train)
# Out:
# D:\juypitor\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GradientBoostingClassifier()

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svm.predict(X_test)
y_pred3 = knn.predict(X_test)
y_pred4 = dt.predict(X_test)
y_pred5 = rf.predict(X_test)
y_pred6 = gb.predict(X_test)
# Out:
# D:\juypitor\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.metrics import accuracy_score

# %%
score1=accuracy_score(Y_test,y_pred1)
score2=accuracy_score(Y_test,y_pred2)
score3=accuracy_score(Y_test,y_pred3)
score4=accuracy_score(Y_test,y_pred4)
score5=accuracy_score(Y_test,y_pred5)
score6=accuracy_score(Y_test,y_pred6)

# %%
final_data = pd.DataFrame({'Models':['LR','SVC','KNN','DT','RF','GB'],
            'ACC':[score1*100,
                  score2*100,
                  score3*100,
                  score4*100,
                  score5*100,score6*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  67.955801
# 1    SVC  64.088398
# 2    KNN  65.193370
# 3     DT  94.475138
# 4     RF  96.685083
# 5     GB  95.027624

# %%
sns.barplot(final_data['Models'],final_data['ACC'])
# Out:
# D:\juypitor\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Models', ylabel='ACC'>

# %%
new_data = pd.DataFrame({
                        'shortlists':0,
                         'college':3,
                         'branch':0,
                         '10th':9,
                         '12th':8,
                         'grad':7,
                         'gap_years':2,
                         'workex_month':24,
                         'workex_sector':0
},index=[0])

# %%
lr= LogisticRegression()
lr.fit(x,y)
# Out:
# D:\juypitor\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
p=lr.predict(new_data)
prob=lr.predict_proba(new_data)
if p==1:
    print('Placed')
    print(f"You will be placed with probability of {prob[0][1]:.2f}")
else:
    print("Not-placed")
# Out:
# Placed
# You will be placed with probability of 0.67
